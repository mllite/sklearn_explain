# %%
from sklearn import datasets
import pandas as pd

# %%
# build a model

ds = datasets.load_breast_cancer();
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=120, random_state = 1960)

clf.fit(ds.data , ds.target)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=120, n_jobs=1, oob_score=False, random_state=1960,
#             verbose=0, warm_start=False)

# %%
# Explain the score


import sklearn_explain.explainer as expl
lExplainer = expl.cModelScoreExplainer(clf)
lExplainer.fit(ds.data)
df_rc = lExplainer.explain(ds.data)

df_rc.head()
# Out:
# USING_PROBABILITY_AS_SCORE
# USING_PROBABILITY_AS_SCORE
#    Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 0      17.99      10.38     122.80     1001.0    0.11840    0.27760
# 1      20.57      17.77     132.90     1326.0    0.08474    0.07864
# 2      19.69      21.25     130.00     1203.0    0.10960    0.15990
# 3      11.42      20.38      77.58      386.1    0.14250    0.28390
# 4      20.29      14.34     135.10     1297.0    0.10030    0.13280
#
#    Feature_7  Feature_8  Feature_9  Feature_10    ...       reason_11  \
# 0     0.3001    0.14710     0.2419     0.07871    ...      Feature_20
# 1     0.0869    0.07017     0.1812     0.05667    ...      Feature_20
# 2     0.1974    0.12790     0.2069     0.05999    ...      Feature_20
# 3     0.2414    0.10520     0.2597     0.09744    ...      Feature_20
# 4     0.1980    0.10430     0.1809     0.05883    ...      Feature_20
#
#     reason_12   reason_13   reason_14   reason_15   reason_16   reason_17  \
# 0  Feature_21  Feature_22  Feature_23  Feature_24  Feature_25  Feature_26
# 1  Feature_21  Feature_22  Feature_23  Feature_24  Feature_25  Feature_26
# 2  Feature_21  Feature_22  Feature_23  Feature_24  Feature_25  Feature_26
# 3  Feature_21  Feature_22  Feature_23  Feature_24  Feature_25  Feature_26
# 4  Feature_21  Feature_22  Feature_23  Feature_24  Feature_25  Feature_26
#
#     reason_18   reason_19  reason_20
# 0  Feature_27  Feature_28  Feature_1
# 1  Feature_27  Feature_28  Feature_1
# 2  Feature_27  Feature_28  Feature_1
# 3  Feature_27  Feature_28  Feature_1
# 4  Feature_27  Feature_28  Feature_1
#
# [5 rows x 112 columns]
