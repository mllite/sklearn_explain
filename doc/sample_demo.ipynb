# %%
from sklearn import datasets
import pandas as pd

# %%
# build a model

ds = datasets.load_breast_cancer();
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=12, random_state = 1960)

X = ds.data
clf.fit(X , ds.target)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=12, n_jobs=1,
#             oob_score=False, random_state=1960, verbose=0,
#             warm_start=False)

# %%
# Explain the score


import sklearn_explain.explainer as expl
lExplainer = expl.cModelScoreExplainer(clf)
lExplainer.mFeatureNames = ds.feature_names
lExplainer.fit(X)
df_rc = lExplainer.explain(X)

df_rc.sample(12, random_state = 1960)
# Out:
# USING_PROBABILITY_AS_SCORE
# USING_PROBABILITY_AS_SCORE
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 50         11.76         21.60           74.72      427.9          0.08637
# 457        13.21         25.25           84.10      537.9          0.08791
# 259        15.53         33.56          103.70      744.9          0.10630
# 85         18.46         18.52          121.10     1075.0          0.09874
# 348        11.47         16.03           73.02      402.7          0.09076
# 462        14.40         26.99           92.25      646.1          0.06995
# 451        19.59         25.00          127.70     1191.0          0.10320
# 293        11.85         17.46           75.54      432.7          0.08372
# 218        19.80         21.56          129.70     1230.0          0.09383
# 219        19.53         32.47          128.00     1223.0          0.08420
# 133        15.71         13.93          102.00      761.7          0.09462
# 192         9.72         18.22           60.73      288.1          0.06950
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 50            0.04966         0.01657              0.01115         0.1495
# 457           0.05205         0.02772              0.02068         0.1619
# 259           0.16390         0.17510              0.08399         0.2091
# 85            0.10530         0.13350              0.08795         0.2132
# 348           0.05886         0.02587              0.02322         0.1634
# 462           0.05223         0.03476              0.01737         0.1707
# 451           0.09871         0.16550              0.09063         0.1663
# 293           0.05642         0.02688              0.02280         0.1875
# 218           0.13060         0.12720              0.08691         0.2094
# 219           0.11300         0.11450              0.06637         0.1428
# 133           0.09462         0.07135              0.05933         0.1816
# 192           0.02344         0.00000              0.00000         0.1653
#
#      mean fractal dimension  \
# 50                  0.05888
# 457                 0.05584
# 259                 0.06650
# 85                  0.06022
# 348                 0.06372
# 462                 0.05433
# 451                 0.05391
# 293                 0.05715
# 218                 0.05581
# 219                 0.05313
# 133                 0.05723
# 192                 0.06447
#
#                            ...                          \
# 50                         ...
# 457                        ...
# 259                        ...
# 85                         ...
# 348                        ...
# 462                        ...
# 451                        ...
# 293                        ...
# 218                        ...
# 219                        ...
# 133                        ...
# 192                        ...
#
#                                        reason_ep1  \
# 50         mean fractal dimension_concavity error
# 457              compactness error_worst symmetry
# 259                 mean compactness_radius error
# 85               mean compactness_worst concavity
# 348                  mean concavity_texture error
# 462                   mean compactness_worst area
# 451  fractal dimension error_worst concave points
# 293                     mean area_mean smoothness
# 218                    area error_concavity error
# 219                   mean symmetry_texture error
# 133           mean radius_worst fractal dimension
# 192              smoothness error_worst concavity
#
#                                      detailed_reason_1  \
# 50   [(0.04996 < 'mean fractal dimension' <= 0.0568...
# 457  [(0.002252 < 'compactness error' <= 0.0118), (...
# 259  [(0.01938 < 'mean compactness' <= 0.059638), (...
# 85   [(0.01938 < 'mean compactness' <= 0.059638), (...
# 348  [(0.0 < 'mean concavity' <= 0.02493), (0.3602 ...
# 462  [(0.01938 < 'mean compactness' <= 0.059638), (...
# 451  [(0.0008948 < 'fractal dimension error' <= 0.0...
# 293  [(143.5 < 'mean area' <= 396.56), (0.05263 < '...
# 218  [(6.802 < 'area error' <= 16.64), (0.0 < 'conc...
# 219  [(0.106 < 'mean symmetry' <= 0.15876), (0.3602...
# 133  [(6.981 < 'mean radius' <= 11.366), (0.05504 <...
# 192  [(0.001713 < 'smoothness error' <= 0.004871), ...
#
#                                    reason_ep2  \
# 50               mean symmetry_symmetry error
# 457             mean texture_worst smoothness
# 259            concavity error_symmetry error
# 85           symmetry error_worst compactness
# 348              mean concavity_worst texture
# 462                concavity error_worst area
# 451          symmetry error_worst compactness
# 293      mean fractal dimension_worst texture
# 218  mean fractal dimension_worst compactness
# 219  mean fractal dimension_worst compactness
# 133            mean perimeter_mean smoothness
# 192        smoothness error_worst compactness
#
#                                      detailed_reason_2  \
# 50   [(0.106 < 'mean symmetry' <= 0.15876), (0.0078...
# 457  [(9.71 < 'mean texture' <= 15.656), (0.07117 <...
# 259  [(0.0 < 'concavity error' <= 0.013212), (0.007...
# 85   [(0.007882 < 'symmetry error' <= 0.01454), (0....
# 348  [(0.0 < 'mean concavity' <= 0.02493), (12.02 <...
# 462  [(0.0 < 'concavity error' <= 0.013212), (185.2...
# 451  [(0.007882 < 'symmetry error' <= 0.01454), (0....
# 293  [(0.04996 < 'mean fractal dimension' <= 0.0568...
# 218  [(0.04996 < 'mean fractal dimension' <= 0.0568...
# 219  [(0.04996 < 'mean fractal dimension' <= 0.0568...
# 133  [(43.79 < 'mean perimeter' <= 73.292), (0.0526...
# 192  [(0.001713 < 'smoothness error' <= 0.004871), ...
#
#                                  reason_ep3  \
# 50            mean texture_smoothness error
# 457    mean fractal dimension_worst texture
# 259              perimeter error_area error
# 85            mean texture_worst smoothness
# 348           texture error_worst concavity
# 462               mean perimeter_worst area
# 451       perimeter error_worst compactness
# 293          mean smoothness_symmetry error
# 218           mean texture_mean compactness
# 219   concave points error_worst smoothness
# 133           mean perimeter_worst symmetry
# 192  mean fractal dimension_concavity error
#
#                                      detailed_reason_3  \
# 50   [(9.71 < 'mean texture' <= 15.656), (0.001713 ...
# 457  [(0.04996 < 'mean fractal dimension' <= 0.0568...
# 259  [(0.757 < 'perimeter error' <= 1.5166), (6.802...
# 85   [(9.71 < 'mean texture' <= 15.656), (0.07117 <...
# 348  [(0.3602 < 'texture error' <= 0.7806), (0.0 < ...
# 462  [(43.79 < 'mean perimeter' <= 73.292), (185.2 ...
# 451  [(0.757 < 'perimeter error' <= 1.5166), (0.027...
# 293  [(0.05263 < 'mean smoothness' <= 0.084206), (0...
# 218  [(9.71 < 'mean texture' <= 15.656), (0.01938 <...
# 219  [(0.0 < 'concave points error' <= 0.0068934), ...
# 133  [(43.79 < 'mean perimeter' <= 73.292), (0.1565...
# 192  [(0.04996 < 'mean fractal dimension' <= 0.0568...
#
#                                    reason_ep4  \
# 50                 perimeter error_area error
# 457             mean texture_smoothness error
# 259                 mean area_perimeter error
# 85            mean compactness_symmetry error
# 348          mean smoothness_worst smoothness
# 462              mean texture_worst perimeter
# 451       worst concave points_worst symmetry
# 293  smoothness error_worst fractal dimension
# 218      mean texture_fractal dimension error
# 219       mean concavity_concave points error
# 133              mean radius_smoothness error
# 192              mean symmetry_symmetry error
#
#                                      detailed_reason_4  \
# 50   [(0.757 < 'perimeter error' <= 1.5166), (6.802...
# 457  [(9.71 < 'mean texture' <= 15.656), (0.001713 ...
# 259  [(143.5 < 'mean area' <= 396.56), (0.757 < 'pe...
# 85   [(0.01938 < 'mean compactness' <= 0.059638), (...
# 348  [(0.05263 < 'mean smoothness' <= 0.084206), (0...
# 462  [(9.71 < 'mean texture' <= 15.656), (50.41 < '...
# 451  [(0.0 < 'worst concave points' <= 0.058086), (...
# 293  [(0.001713 < 'smoothness error' <= 0.004871), ...
# 218  [(9.71 < 'mean texture' <= 15.656), (0.0008948...
# 219  [(0.0 < 'mean concavity' <= 0.02493), (0.0 < '...
# 133  [(6.981 < 'mean radius' <= 11.366), (0.001713 ...
# 192  [(0.106 < 'mean symmetry' <= 0.15876), (0.0078...
#
#                                          reason_ep5  \
# 50                     mean texture_perimeter error
# 457                   worst texture_worst perimeter
# 259                          mean area_radius error
# 85                    mean texture_smoothness error
# 348                    worst texture_worst symmetry
# 462                   worst texture_worst perimeter
# 451          worst compactness_worst concave points
# 293              texture error_concave points error
# 218  mean fractal dimension_fractal dimension error
# 219  mean fractal dimension_fractal dimension error
# 133                     mean compactness_worst area
# 192                compactness error_worst symmetry
#
#                                      detailed_reason_5
# 50   [(9.71 < 'mean texture' <= 15.656), (0.757 < '...
# 457  [(12.02 < 'worst texture' <= 20.176), (50.41 <...
# 259  [(143.5 < 'mean area' <= 396.56), (0.1115 < 'r...
# 85   [(9.71 < 'mean texture' <= 15.656), (0.001713 ...
# 348  [(12.02 < 'worst texture' <= 20.176), (0.1565 ...
# 462  [(12.02 < 'worst texture' <= 20.176), (50.41 <...
# 451  [(0.02729 < 'worst compactness' <= 0.12566), (...
# 293  [(0.3602 < 'texture error' <= 0.7806), (0.0 < ...
# 218  [(0.04996 < 'mean fractal dimension' <= 0.0568...
# 219  [(0.04996 < 'mean fractal dimension' <= 0.0568...
# 133  [(0.01938 < 'mean compactness' <= 0.059638), (...
# 192  [(0.002252 < 'compactness error' <= 0.0118), (...
#
# [12 rows x 1382 columns]
